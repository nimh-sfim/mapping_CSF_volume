# %%
import pandas as pd

# %%
pd.read_csv('../../PrcsData/SBJ01/SES01/run1/melodic_concat/melodic_mix', delim_whitespace=True, header=None)
# Out:
# /tmp/ipykernel_3433633/10366630.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pd.read_csv('../../PrcsData/SBJ01/SES01/run1/melodic_concat/melodic_mix', delim_whitespace=True, header=None)
#             0          1         2         3          4         5          6   \
# 0    -0.007751  -0.008561  0.023313 -0.000298  -0.005333  0.015075   0.002432
# 1     0.000638  -0.006781 -0.003246 -0.054619  -0.012313 -0.013069   0.003386
# 2     0.002759   0.004892  0.019637 -0.005065  -0.006092  0.007295   0.011310
# 3    -0.004921   0.007376  0.022042 -0.003222   0.001289 -0.014588   0.008899
# 4    -0.001892  -0.001973  0.030304 -0.024173  -0.015844 -0.015311   0.009968
# ..         ...        ...       ...       ...        ...       ...        ...
# 156  -2.653053   1.015666 -1.461703 -1.220942  -0.482574 -0.767432   2.156182
# ...

# %%
pwd
# Out:
# '/vf/users/SFIM_CSF_Volume/Project01/Code/notebook'

# %%
ls ../../PrcsData/SBJ01/SES01/run1/melodic_concat/melodic_mix
# Out:
# ../../PrcsData/SBJ01/SES01/run1/melodic_concat/melodic_mix
